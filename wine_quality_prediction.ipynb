# %% [markdown]
# ### WINE QUALITY CLASSIFICATION USING MAHINE **LEARNING**

# %% [markdown]
# **Objective:**
# To build a machine learning model that classifies wines into different quality categories based on physicochemical properties such as acidity, sugar, alcohol content, and pH level. bold text

# %% [markdown]
# **Steps Followed:**
# 1)Data Collection: The dataset was collected from UCI Machine Learning Repository / Kaggle.
#
# ## **The features in the dataset are: fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, and quality.

# %% [markdown]
# 2)Problem Statement
# The goal of this project is to predict the quality of wine based on its chemical features.
#
# This is a classification problem in machine learning.
#
# We will use the features like acidity, sugar, alcohol, etc., to train a model that can classify the wine as good or bad quality.

# %% [markdown]
# ### **3)EDA-1**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Binary Classification- Converted wine quality scores into two categogies and helps all models reach 80%+ accuracy

df['quality'] = df['quality'].apply(lambda x: 1 if x >= 6 else 0)

# %%
df['quality']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1138    1
# 1139    1
# 1140    0
# 1141    1
# 1142    0
# Name: quality, Length: 1143, dtype: int64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        0   0
# 1      9.8        0   1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df.drop("Id",axis=1,inplace=True)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %% [markdown]
# ## **Univariate Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(bins=20,figsize=(15,10))
plt.suptitle("Univariate Analysis-Histograms",fontsize=16)
plt.show()

# %% [markdown]
# **Boxplots to Check Outliers**

# %%
features = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
            'chlorides', 'free sulfur dioxide', 'total sulfur dioxide',
            'density', 'pH', 'sulphates', 'alcohol']

# %%
df = df.select_dtypes(include=['float64', 'int64'])

# Plot boxplots for all features
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, orient='h', palette='Set2')
plt.title("Boxplot of All Features")
plt.tight_layout()
plt.show()

# %%
print(df['quality'].value_counts())

sns.countplot(x='quality', data=df)
plt.title("Wine Quality Distribution")
plt.show()
# Out:
# quality
# 1    621
# 0    522
# Name: count, dtype: int64

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.boxplot(x='quality', y='alcohol', data=df, palette='Set2')
plt.title('Alcohol vs Quality')
plt.show()
# Out:
# /tmp/ipython-input-528-3340241591.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y='alcohol', data=df, palette='Set2')

# %%
sns.boxplot(x='quality', y='pH', data=df)
sns.boxplot(x='quality', y='sulphates', data=df)
sns.boxplot(x='quality', y='volatile acidity', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between All Features")
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
# Handle Outliers

plt.figure(figsize=(20,10))
sns.boxplot(data=df)
plt.title("Outliers in Features")
plt.show()

# %%
# Remove Outliers using IQR


Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df1 = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Plot boxplots for all features
plt.figure(figsize=(12, 8))
sns.boxplot(data=df1, orient='h', palette='Set2')
plt.title("Boxplot of All Features")
plt.tight_layout()
plt.show()

# %%
# Split Data for Training and Testing


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaler, y, test_size=0.2, random_state=42,stratify=y)

# %%
X_train, X_test, y_train, y_test
# Out:
# (array([[-1.32303122, -0.17453512, -1.36502663, ...,  0.31281309,
#          -1.21948518, -0.87093663],
#         [ 1.13857013, -0.67577542,  0.771293  , ..., -0.77278634,
#          -0.22138836, -0.87093663],
#         [ 0.62335125, -1.06562899,  0.51696924, ..., -0.58120997,
#          -0.22138836, -1.14827218],
#         ...,
#         [ 0.68059779,  1.96965951,  0.00832171, ..., -0.45349239,
#          -0.74979256, -0.96338181],
#         [ 0.68059779, -0.39730859,  1.12734627, ..., -0.64506876,
#           0.42443899,  0.51574115],
#         [-0.46433307,  0.27101182, -1.21243237, ..., -1.85838577,
#          -1.10206203, -1.14827218]]),
#  array([[ 0.33711853, -1.23270909,  0.46610448, ...,  0.56824825,
#           0.18959268,  1.25530262],
#         [-0.06360727, -1.62256266,  0.36437498, ..., -0.58120997,
#           1.65738212,  0.42329596],
#         [-1.78100356, -0.28592185, -1.16156762, ...,  1.46227132,
#          -0.22138836,  1.62508336],
#         ...,
# ...

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler

X = df.drop('quality', axis=1)
y = df['quality']

scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)

# %%
X_scaler
# Out:
# array([[-0.52157961,  0.93933222, -1.36502663, ...,  1.27069495,
#         -0.57365783, -0.96338181],
#        [-0.29259344,  1.94181282, -1.36502663, ..., -0.70892755,
#          0.1308811 , -0.59360107],
#        [-0.29259344,  1.27349242, -1.16156762, ..., -0.32577481,
#         -0.04525363, -0.59360107],
#        ...,
#        [-1.20853813,  0.38239855, -0.9581086 , ...,  0.88754221,
#         -0.45623467,  0.05351522],
#        [-1.38027776,  0.10393172, -0.8563791 , ...,  1.33455374,
#          0.60057372,  0.70063152],
#        [-1.38027776,  0.6330187 , -0.75464959, ...,  1.65384769,
#          0.30701583, -0.22382033]])

# %%
# Min-Max Scaling

from sklearn.preprocessing import MinMaxScaler

X = df.drop('quality', axis=1)
y = df['quality']

scaler = MinMaxScaler()
x_scaler = scaler.fit_transform(X)

# %%
x_scaler
# Out:
# array([[0.24778761, 0.39726027, 0.        , ..., 0.60629921, 0.13772455,
#         0.15384615],
#        [0.28318584, 0.52054795, 0.        , ..., 0.36220472, 0.20958084,
#         0.21538462],
#        [0.28318584, 0.43835616, 0.04      , ..., 0.40944882, 0.19161677,
#         0.21538462],
#        ...,
#        [0.14159292, 0.32876712, 0.08      , ..., 0.55905512, 0.1497006 ,
#         0.32307692],
#        [0.11504425, 0.29452055, 0.1       , ..., 0.61417323, 0.25748503,
#         0.43076923],
#        [0.11504425, 0.35958904, 0.12      , ..., 0.65354331, 0.22754491,
#         0.27692308]])

# %% [markdown]
# ## **Model Evaluation & Comparison**

# %%
## Models
# K-Nearest Neighbors
# Logistic Regression
# Decision Tree
# Random Forest
# XGBoost Classifier
## With Hyperparameter tuning using tools are GridSearchCV and RandomSearchCV,Optuna

## Comparing them using accuracy score,F1-Score,Confusion matrix

# %%
# !pip install optuna

# %%
# K-Nearest Neighbous(KNN) with GridSearchCV

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from xgboost import XGBClassifier
import optuna
from scipy.stats import randint

# Define parameter grid
knn_params = {'n_neighbors': [3, 5, 7, 9]}

# Create GridSearchCV
knn_grid = GridSearchCV(KNeighborsClassifier(), knn_params, cv=5, scoring='accuracy')
knn_grid.fit(X_train, y_train)

# Predict
knn_predict = knn_grid.predict(X_test)

# Evaluate
print("KNN")
print("Best Params:", knn_grid.best_params_)
print("Accuracy:", round(accuracy_score(y_test, knn_predict) * 100, 2), "%")
print("F1 Score:", round(f1_score(y_test, knn_predict, average='macro'), 3))
print("Confusion Matrix:\n", confusion_matrix(y_test, knn_predict))
print("Classification Report:\n", classification_report(y_test, knn_predict))
# Out:
# KNN
# Best Params: {'n_neighbors': 3}
# Accuracy: 87.34 %
# F1 Score: 0.709
# Confusion Matrix:
#  [[186  11]
#  [ 18  14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       197
#            1       0.56      0.44      0.49        32
#
#     accuracy                           0.87       229
#    macro avg       0.74      0.69      0.71       229
# weighted avg       0.86      0.87      0.87       229

# %%
# Logistic Regression with GridSearch

from sklearn.linear_model import LogisticRegression

# Define parameter grid
logreg_params = {
    'C': [0.01, 0.1, 1, 10],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear']
}

# Create GridSearchCV
logreg_grid = GridSearchCV(LogisticRegression(max_iter=1000), logreg_params, cv=5, scoring='accuracy')
logreg_grid.fit(X_train, y_train)
# Predict
logreg_predict = logreg_grid.predict(X_test)

# Evaluate
print("Logistic Regression")
print("Best Parameters:", logreg_grid.best_params_)
print("Accuracy:", round(accuracy_score(y_test, logreg_predict) * 100, 2), "%")
print("F1 Score:", round(f1_score(y_test, logreg_predict, average='macro'), 3))
print("Confusion Matrix:\n", confusion_matrix(y_test, logreg_predict))
print("Classification Report:\n", classification_report(y_test, logreg_predict))
# Out:
# Logistic Regression
# Best Parameters: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# Accuracy: 86.46 %
# F1 Score: 0.658
# Confusion Matrix:
#  [[188   9]
#  [ 22  10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92       197
#            1       0.53      0.31      0.39        32
#
#     accuracy                           0.86       229
#    macro avg       0.71      0.63      0.66       229
# weighted avg       0.84      0.86      0.85       229

# %%
 # DecisionTree with GridSearchCV

from sklearn.tree import DecisionTreeClassifier

# Define parameter grid
tree_params = {'max_depth': [5, 10, 15], 'criterion': ['gini', 'entropy']}

# Create GridSearchCV
tree_grid = GridSearchCV(DecisionTreeClassifier(), tree_params, cv=5, scoring='accuracy')
tree_grid.fit(X_train, y_train)

# Predict
tree_predict = tree_grid.predict(X_test)

# Evaluate
print("Decision Tree")
print("Best Parameters:", tree_grid.best_params_)
print("Accuracy:", round(accuracy_score(y_test, tree_predict) * 100, 2), "%")
print("F1 Score:", round(f1_score(y_test, tree_predict, average='macro'), 3))
print("Confusion Matrix:\n", confusion_matrix(y_test, tree_predict))
print("Classification Report:\n", classification_report(y_test, tree_predict))
# Out:
# Decision Tree
# Best Parameters: {'criterion': 'gini', 'max_depth': 5}
# Accuracy: 86.46 %
# F1 Score: 0.715
# Confusion Matrix:
#  [[182  15]
#  [ 16  16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       197
#            1       0.52      0.50      0.51        32
#
#     accuracy                           0.86       229
#    macro avg       0.72      0.71      0.71       229
# weighted avg       0.86      0.86      0.86       229

# %%
# RandomForest with RandomizedSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# Define random search space
rf_params = {
    'n_estimators': randint(50, 150),
    'max_depth': randint(3, 15),
    'max_features': ['sqrt', 'log2']
}

# Create RandomizedSearchCV
rf_random = RandomizedSearchCV(RandomForestClassifier(random_state=42), rf_params,n_iter=10, cv=5, scoring='accuracy', random_state=42)
rf_random.fit(X_train, y_train)

# Predict
rf_predict = rf_random.predict(X_test)

# Evaluate
print("Random Forest")
print("Best Parameters:", rf_random.best_params_)
print("Accuracy:", round(accuracy_score(y_test, rf_predict) * 100, 2), "%")
print("F1 Score:", round(f1_score(y_test, rf_predict, average='macro'), 3))
print("Confusion Matrix:\n", confusion_matrix(y_test, rf_predict))
print("Classification Report:\n", classification_report(y_test, rf_predict))
# Out:
# Random Forest
# Best Parameters: {'max_depth': 13, 'max_features': 'log2', 'n_estimators': 110}
# Accuracy: 91.7 %
# F1 Score: 0.804
# Confusion Matrix:
#  [[192   5]
#  [ 14  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       197
#            1       0.78      0.56      0.65        32
#
#     accuracy                           0.92       229
#    macro avg       0.86      0.77      0.80       229
# weighted avg       0.91      0.92      0.91       229

# %%
# XGBoost Classification with RandomSearch

from xgboost import XGBClassifier

# Define XGBoost model
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Define parameter distribution for Random Search
xgb_params = {
    'n_estimators': randint(100, 300),
    'max_depth': randint(3, 10),
    'learning_rate': uniform(0.01, 0.3),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 5)
}

# Create RandomizedSearchCV
xgb_random = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=xgb_params,
    n_iter=20,
    cv=5,
    scoring='accuracy',
    random_state=42,
    n_jobs=-1
)

# Fit model
xgb_random.fit(X_train, y_train)

# Predict
xgb_pred = xgb_random.predict(X_test)

# Evaluate
print("XGBoost - RandomizedSearchCV")
print("Best Parameters:", xgb_random.best_params_)
print("Accuracy:", round(accuracy_score(y_test, xgb_pred) * 100, 2), "%")
print("F1 Score:", round(f1_score(y_test, xgb_pred, average='macro'), 3))
print("Confusion Matrix:\n", confusion_matrix(y_test, xgb_pred))
print("Classification Report:\n", classification_report(y_test, xgb_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:49:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - RandomizedSearchCV
# Best Parameters: {'colsample_bytree': np.float64(0.7541666010159664), 'gamma': np.float64(0.07983126110107097), 'learning_rate': np.float64(0.0792681476866447), 'max_depth': 6, 'n_estimators': 210, 'subsample': np.float64(0.8733054075301833)}
# Accuracy: 91.27 %
# F1 Score: 0.803
# Confusion Matrix:
#  [[190   7]
#  [ 13  19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       197
#            1       0.73      0.59      0.66        32
#
#     accuracy                           0.91       229
#    macro avg       0.83      0.78      0.80       229
# weighted avg       0.91      0.91      0.91       229

# %%
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# quality
# 0    787
# 1    127
# Name: count, dtype: int64
# quality
# 0    197
# 1     32
# Name: count, dtype: int64
